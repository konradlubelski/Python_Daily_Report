# %%
# !pip install --upgrade openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
data = pd.read_excel("DD.MM.xlsx")
# !pip install xlsxwriter
import xlsxwriter
writer = pd.ExcelWriter('Podsumowanie DD.MM.xlsx', engine = 'xlsxwriter')

# %%
#Lubuskie
lubuskie = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "lubuskie")]
netto_lubuskie = lubuskie['Zmiana wartości N/B'].sum()
dział_handlowy = 1
działy_sklepowe = [101, 102, 103, 104, 105, 107, 108, 109]

lubuskie_handlowy = lubuskie.loc[lubuskie['Dział'] == dział_handlowy]
netto_lubuskie_handlowy = lubuskie_handlowy['Zmiana wartości N/B'].sum()
netto_lubuskie_handlowy

sklepy_lubuskie = 0
for dział in działy_sklepowe:
  for ind in lubuskie.index:
    if lubuskie['Dział'][ind] == dział and lubuskie['Numerator_MPK'][ind] == 1:
      sklepy_lubuskie += 0.5 * lubuskie['Zmiana wartości N/B'][ind]
sklepy_lubuskie

całość_lubuskie = netto_lubuskie_handlowy + sklepy_lubuskie

całość_lubuskie
# Out:
# 41230.28

# %%
#Zachodniopomorskie
zachodniopomorskie = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "zachodniopomorskie")]
netto_zachodniopomorskie = zachodniopomorskie['Zmiana wartości N/B'].sum()

zachodniopomorskie_handlowy = zachodniopomorskie.loc[zachodniopomorskie['Dział'] == dział_handlowy]
netto_zachodniopomorskie_handlowy = zachodniopomorskie_handlowy['Zmiana wartości N/B'].sum()
netto_zachodniopomorskie_handlowy

sklepy_zachodniopomorskie = 0
for dział in działy_sklepowe:
  for ind in zachodniopomorskie.index:
    if zachodniopomorskie['Dział'][ind] == dział and zachodniopomorskie['Numerator_MPK'][ind] == 1:
      sklepy_zachodniopomorskie += 0.5 * zachodniopomorskie['Zmiana wartości N/B'][ind]
sklepy_zachodniopomorskie

całość_zachodniopomorskie = netto_zachodniopomorskie_handlowy + sklepy_zachodniopomorskie

całość_zachodniopomorskie
# Out:
# 63888.44499999999

# %%
#Podlaskie
podlaskie = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "podlaskie")]
netto_podlaskie = podlaskie['Zmiana wartości N/B'].sum()

podlaskie_handlowy = podlaskie.loc[podlaskie['Dział'] == 1]
netto_podlaskie_handlowy = podlaskie_handlowy['Zmiana wartości N/B'].sum()
netto_podlaskie_handlowy

sklepy_podlaskie = 0
for dział in działy_sklepowe:
  for ind in podlaskie.index:
    if podlaskie['Dział'][ind] == dział and podlaskie['Numerator_MPK'][ind] == 1:
      sklepy_podlaskie += 0.5 * podlaskie['Zmiana wartości N/B'][ind]
sklepy_podlaskie

całość_podlaskie = netto_podlaskie_handlowy + sklepy_podlaskie

całość_podlaskie
sklepy_podlaskie
netto_podlaskie_handlowy
# Out:
# 29025.42

# %%
#WM Wschód
wm_wschód = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "warmińsko-mazurskie")]
netto_wm_wschód = wm_wschód['Zmiana wartości N/B'].sum()

wm_wschód_handlowy = wm_wschód.loc[wm_wschód['Dział'] == 1]
netto_wm_wschód_handlowy = wm_wschód_handlowy['Zmiana wartości N/B'].sum()
netto_wm_wschód_handlowy

sklepy_wm_wschód = 0
for dział in działy_sklepowe:
  for ind in wm_wschód.index:
    if wm_wschód['Dział'][ind] == dział and wm_wschód['Numerator_MPK'][ind] == 1:
      sklepy_wm_wschód += 0.5 * wm_wschód['Zmiana wartości N/B'][ind]
sklepy_wm_wschód

całość_wm_wschód = netto_wm_wschód_handlowy + sklepy_wm_wschód

całość_wm_wschód
# Out:
# 11316.59

# %%
#Śląskie
śląskie = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "śląskie") & (data['Nazwa'] != 'XYZ')]
netto_śląskie = śląskie['Zmiana wartości N/B'].sum()

śląskie_handlowy = śląskie.loc[śląskie['Dział'] == 1]
netto_śląskie_handlowy = śląskie_handlowy['Zmiana wartości N/B'].sum()
netto_śląskie_handlowy

sklepy_śląskie = 0
for dział in działy_sklepowe:
  for ind in śląskie.index:
    if śląskie['Dział'][ind] == dział and śląskie['Numerator_MPK'][ind] == 1:
      sklepy_śląskie += 0.5 * śląskie['Zmiana wartości N/B'][ind]
sklepy_śląskie

całość_śląskie = netto_śląskie_handlowy + sklepy_śląskie

całość_śląskie
# Out:
# 50091.674999999996

# %%
#Dolnośląskie
dolnośląskie = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "dolnośląskie")]
netto_dolnośląskie = dolnośląskie['Zmiana wartości N/B'].sum()

dolnośląskie_handlowy = dolnośląskie.loc[dolnośląskie['Dział'] == 1]
netto_dolnośląskie_handlowy = dolnośląskie_handlowy['Zmiana wartości N/B'].sum()
netto_dolnośląskie_handlowy

sklepy_dolnośląskie = 0
for dział in działy_sklepowe:
  for ind in dolnośląskie.index:
    if dolnośląskie['Dział'][ind] == dział and dolnośląskie['Numerator_MPK'][ind] == 1:
      sklepy_dolnośląskie += 0.5 * dolnośląskie['Zmiana wartości N/B'][ind]
sklepy_dolnośląskie

całość_dolnośląskie = netto_dolnośląskie_handlowy + sklepy_dolnośląskie

całość_dolnośląskie
# Out:
# 289447.385

# %%
#Opolskie
opolskie = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "opolskie")]
netto_opolskie = opolskie['Zmiana wartości N/B'].sum()

opolskie_handlowy = opolskie.loc[opolskie['Dział'] == 1]
netto_opolskie_handlowy = opolskie_handlowy['Zmiana wartości N/B'].sum()
netto_opolskie_handlowy

sklepy_opolskie = 0
for dział in działy_sklepowe:
  for ind in opolskie.index:
    if opolskie['Dział'][ind] == dział and opolskie['Numerator_MPK'][ind] == 1:
      sklepy_opolskie += 0.5 * opolskie['Zmiana wartości N/B'][ind]
sklepy_opolskie

całość_opolskie = netto_opolskie_handlowy + sklepy_opolskie

całość_opolskie
# Out:
# 9197.439999999999

# %%
#Wielkopolska

wielkopolskie = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "wielkopolskie")]
netto_wielkopolskie = wielkopolskie['Zmiana wartości N/B'].sum()

wielkopolskie_handlowy = wielkopolskie.loc[wielkopolskie['Dział'] == 1]
netto_wielkopolskie_handlowy = wielkopolskie_handlowy['Zmiana wartości N/B'].sum()
netto_wielkopolskie_handlowy


sklepy_wielkopolskie = 0
for dział in działy_sklepowe:
  for ind in wielkopolskie.index:
    if wielkopolskie['Dział'][ind] == dział and wielkopolskie['Numerator_MPK'][ind] == 1:
      sklepy_wielkopolskie += 0.5 * wielkopolskie['Zmiana wartości N/B'][ind]
sklepy_wielkopolskie

XYZ = data.loc[(data['Nazwa'] == "XYZ") 
                           & (data['Opis'].str.contains('Poz|poz'))]

całość_wielkopolskie = netto_wielkopolskie_handlowy + sklepy_wielkopolskie + SAS_Poznań['Zmiana wartości N/B'].sum()

całość_wielkopolskie
XYZ['Zmiana wartości N/B'].sum()
# Out:
# 1508.9

# %%
#Lubelskie
lubelskie = data.loc[((data['RKS'] == "Jan Nowak") | (data['RKS'] == "Jan Nowak")) & (data['Wojewodztwo']== "lubelskie")]
netto_lubelskie = lubelskie['Zmiana wartości N/B'].sum()

lubelskie_handlowy = lubelskie.loc[lubelskie['Dział'] == 1]
netto_lubelskie_handlowy = lubelskie_handlowy['Zmiana wartości N/B'].sum()
netto_lubelskie_handlowy

sklepy_lubelskie = 0
for dział in działy_sklepowe:
  for ind in lubelskie.index:
    if lubelskie['Dział'][ind] == dział and lubelskie['Numerator_MPK'][ind] == 1:
      sklepy_lubelskie += 0.5 * lubelskie['Zmiana wartości N/B'][ind]
sklepy_lubelskie

całość_lubelskie = netto_lubelskie_handlowy + sklepy_lubelskie

całość_lubelskie
# Out:
# 20061.42

# %%
#Małopolskie

małopolskie = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "małopolskie")]
netto_małopolskie = małopolskie['Zmiana wartości N/B'].sum()

małopolskie_handlowy = małopolskie.loc[małopolskie['Dział'] == 1]
netto_małopolskie_handlowy = małopolskie_handlowy['Zmiana wartości N/B'].sum()
netto_małopolskie_handlowy

sklepy_małopolskie = 0
for dział in działy_sklepowe:
  for ind in małopolskie.index:
    if małopolskie['Dział'][ind] == dział and małopolskie['Numerator_MPK'][ind] == 1:
      sklepy_małopolskie += 0.5 * małopolskie['Zmiana wartości N/B'][ind]
sklepy_małopolskie

całość_małopolskie = netto_małopolskie_handlowy + sklepy_małopolskie

całość_małopolskie
# Out:
# 263453.425

# %%
#Mazowieckie
mazowieckie = data.loc[data['Wojewodztwo']== "mazowieckie"]
netto_mazowieckie = mazowieckie['Zmiana wartości N/B'].sum()

mazowieckie_handlowy = mazowieckie.loc[(mazowieckie['Dział'] == 1) & (mazowieckie['Numerator_MPK'] == 1)]
netto_mazowieckie_handlowy = mazowieckie_handlowy['Zmiana wartości N/B'].sum()
netto_mazowieckie_handlowy

sklepy_mazowieckie = 0
for dział in działy_sklepowe:
  for ind in mazowieckie.index:
    if mazowieckie['Dział'][ind] == dział and mazowieckie['Numerator_MPK'][ind] == 1:
      sklepy_mazowieckie += 0.5 * mazowieckie['Zmiana wartości N/B'][ind]
sklepy_mazowieckie

całość_mazowieckie = netto_mazowieckie_handlowy + sklepy_mazowieckie

całość_mazowieckie
# Out:
# 98407.65000000001

# %%
#Łódzkie
łódzkie = data.loc[data['Wojewodztwo']== "łódzkie"]
netto_łódzkie = łódzkie['Zmiana wartości N/B'].sum()

łódzkie_handlowy = łódzkie.loc[łódzkie['Dział'] == 1]
netto_łódzkie_handlowy = łódzkie_handlowy['Zmiana wartości N/B'].sum()
netto_łódzkie_handlowy

sklepy_łódzkie = 0
for dział in działy_sklepowe:
  for ind in łódzkie.index:
    if łódzkie['Dział'][ind] == dział and łódzkie['Numerator_MPK'][ind] == 1:
      sklepy_łódzkie += 0.5 * łódzkie['Zmiana wartości N/B'][ind]
sklepy_łódzkie

całość_łódzkie = netto_łódzkie_handlowy + sklepy_łódzkie

całość_łódzkie
# Out:
# 33949.955

# %%
#Podkarpackie
podkarpackie = data.loc[data['Wojewodztwo']== "podkarpackie"]
netto_podkarpackie = podkarpackie['Zmiana wartości N/B'].sum()

podkarpackie_handlowy = podkarpackie.loc[podkarpackie['Dział'] == 1]
netto_podkarpackie_handlowy = podkarpackie_handlowy['Zmiana wartości N/B'].sum()
netto_podkarpackie_handlowy

sklepy_podkarpackie = 0
for dział in działy_sklepowe:
  for ind in podkarpackie.index:
    if podkarpackie['Dział'][ind] == dział and podkarpackie['Numerator_MPK'][ind] == 1:
      sklepy_podkarpackie += 0.5 * podkarpackie['Zmiana wartości N/B'][ind]
sklepy_podkarpackie

XYZ = data.loc[data['Nazwa'] == 'XYZ']

XYZ_netto = XYZ['Zmiana wartości N/B'].sum()

całość_podkarpackie = netto_podkarpackie_handlowy + sklepy_podkarpackie + XYZ_netto

całość_podkarpackie
# Out:
# 33776.87

# %%
#Świętokrzyskie
świętokrzyskie = data.loc[data['Wojewodztwo']== "świętokrzyskie"]
netto_świętokrzyskie = świętokrzyskie['Zmiana wartości N/B'].sum()

świętokrzyskie_handlowy = świętokrzyskie.loc[świętokrzyskie['Dział'] == 1]
netto_świętokrzyskie_handlowy = świętokrzyskie_handlowy['Zmiana wartości N/B'].sum()
netto_świętokrzyskie_handlowy

sklepy_świętokrzyskie = 0
for dział in działy_sklepowe:
  for ind in świętokrzyskie.index:
    if świętokrzyskie['Dział'][ind] == dział and świętokrzyskie['Numerator_MPK'][ind] == 1:
      sklepy_świętokrzyskie += 0.5 * świętokrzyskie['Zmiana wartości N/B'][ind]
sklepy_świętokrzyskie

całość_świętokrzyskie = netto_świętokrzyskie_handlowy + sklepy_świętokrzyskie

całość_świętokrzyskie
# Out:
# 2243.66

# %%
#Kujawsko-Pomorskie
kujawsko_pomorskie = data.loc[data['Wojewodztwo']== "kujawsko-pomorskie"]
netto_kujawsko_pomorskie = kujawsko_pomorskie['Zmiana wartości N/B'].sum()

kujawsko_pomorskie_handlowy = kujawsko_pomorskie.loc[kujawsko_pomorskie['Dział'] == 1]
netto_kujawsko_pomorskie_handlowy = kujawsko_pomorskie_handlowy['Zmiana wartości N/B'].sum()
netto_kujawsko_pomorskie_handlowy

sklepy_kujawsko_pomorskie = 0
for dział in działy_sklepowe:
  for ind in kujawsko_pomorskie.index:
    if kujawsko_pomorskie['Dział'][ind] == dział and kujawsko_pomorskie['Numerator_MPK'][ind] == 1:
      sklepy_kujawsko_pomorskie += 0.5 * kujawsko_pomorskie['Zmiana wartości N/B'][ind]
sklepy_kujawsko_pomorskie

całość_kujawsko_pomorskie = netto_kujawsko_pomorskie_handlowy + sklepy_kujawsko_pomorskie

całość_kujawsko_pomorskie
# Out:
# 4491.68

# %%
#Pomorskie
pomorskie = data.loc[data['Wojewodztwo']== "pomorskie"]
netto_pomorskie = pomorskie['Zmiana wartości N/B'].sum()

pomorskie_handlowy = pomorskie.loc[pomorskie['Dział'] == 1]
netto_pomorskie_handlowy = pomorskie_handlowy['Zmiana wartości N/B'].sum()
netto_pomorskie_handlowy

sklepy_pomorskie = 0
for dział in działy_sklepowe:
  for ind in pomorskie.index:
    if pomorskie['Dział'][ind] == dział and pomorskie['Numerator_MPK'][ind] == 1:
      sklepy_pomorskie += 0.5 * pomorskie['Zmiana wartości N/B'][ind]
sklepy_pomorskie

całość_pomorskie = netto_pomorskie_handlowy + sklepy_pomorskie

całość_pomorskie
# Out:
# 23811.844999999998

# %%
#Warmińsko-Mazurskie ZACHÓD
wm_zachód = data.loc[(data['RKS'] == "Jan Nowak") & (data['Wojewodztwo']== "warmińsko-mazurskie")]
netto_wm_zachód = wm_zachód['Zmiana wartości N/B'].sum()

wm_zachód_handlowy = wm_zachód.loc[wm_zachód['Dział'] == 1]
netto_wm_zachód_handlowy = wm_zachód_handlowy['Zmiana wartości N/B'].sum()
netto_wm_zachód_handlowy

sklepy_wm_zachód = 0
for dział in działy_sklepowe:
  for ind in wm_zachód.index:
    if wm_zachód['Dział'][ind] == dział and wm_zachód['Numerator_MPK'][ind] == 1:
      sklepy_wm_zachód += 0.5 * wm_zachód['Zmiana wartości N/B'][ind]
sklepy_wm_zachód

całość_wm_zachód = netto_wm_zachód_handlowy + sklepy_wm_zachód

całość_wm_zachód
# Out:
# 3470.0

# %%
#RKS-i (bez lub z Grafenem)
data_frame = {'Wynik_netto':[całość_lubuskie - XYZ['Zmiana wartości N/B'].sum(), całość_zachodniopomorskie,
                             całość_podlaskie, całość_wm_wschód,
                             całość_śląskie, całość_dolnośląskie,
                             całość_opolskie,
                             całość_wielkopolskie,
                             całość_lubelskie, całość_małopolskie,
                             całość_mazowieckie, całość_łódzkie,
                             całość_podkarpackie, całość_świętokrzyskie,
                             całość_kujawsko_pomorskie, całość_pomorskie,
                             całość_wm_zachód]}
data_to_excel = pd.DataFrame( data_frame, index = ['Lubuskie', 'Zachodniopomorskie',
                                                   'Podlaskie', 'Warmińsko-Mazurskie WSCHÓD',
                                                   'Śląskie', 'Dolnośląskie', 'Opolskie',
                                                   'Wielkopolska', 'Lubelskie', 'Małopolskie',
                                                   'Mazowieckie', 'Łódzkie', 'Podkarpackie',
                                                   'Świętokrzyskie', 'Kujawsko-Pomorskie',
                                                   'Pomorskie', 'Warmińsko-Mazurskie ZACHÓD'])

print(data_to_excel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 20 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> #RKS-i (bez lub z Grafenem)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> data_frame = {'Wynik_netto':[całość_lubuskie - XYZ['Zmiana wartości N/B'].sum(), całość_zachodniopomorskie,
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a>                              całość_podlaskie, całość_wm_wschód,
# ...

# %%
#Klienci firmowi 
kf = ['XYZ', 'XYZ']
kf_ramka = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in kf:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma:
      suma += data['Zmiana wartości N/B'][ind]
  kf_ramka = kf_ramka.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
kf_ramka
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 21 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> #Klienci firmowi
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> kf = ['XYZ', 'XYZ']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> kf_ramka = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])
# ...

# %%
#Sieci handlowe
sieci = ['XYZ', 'XYZ', 'XYZ',
         'XYZ']
sieci_handlowe = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in sieci:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma:
      suma += data['Zmiana wartości N/B'][ind]
  sieci_handlowe = sieci_handlowe.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
sieci_handlowe
# Out:
#                               Firma  Wynik Netto
# 0    TRANSGOURMET POLSKA SP. Z O.O.     77327.07
# 1  Makro Cash and Carry Polska S.A.     97385.90
# 2               TERG SPÓŁKA AKCYJNA      2041.36
# 3               EURO-NET SP. Z O.O.         0.00

# %%
#Kluczowi klienci
kluczowi_klienci = data[(data['Numerator_MPK'] == 2)]
netto_kluczowi_klienci = kluczowi_klienci['Zmiana wartości N/B'].sum()

# %%
data_frame_2 =  {'Wynik netto': [netto_kluczowi_klienci]}
data_to_excel_2 = pd.DataFrame(data_frame_2, index= ['Kluczowi Klienci'])
print(data_to_excel_2)
# Out:
#                   Wynik netto
# Kluczowi Klienci    258729.76

# %%
# Kluczowi klienci - wszystko
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ']
kluczowi_klienci = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for company in lista:
  lista[lista.index(company)] = 'XYZ'

print(lista)


for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]

  kluczowi_klienci = kluczowi_klienci.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
kluczowi_klienci
# Out:
# ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 25 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X33sZmlsZQ%3D%3D?line=13'>14</a> suma = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X33sZmlsZQ%3D%3D?line=14'>15</a> sklepy = 0
# ...

# %%
# Firmy lubuskie (bez Grafenu)
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_lubuskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_lubuskie = firmy_lubuskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_lubuskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 26 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X34sZmlsZQ%3D%3D?line=6'>7</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X34sZmlsZQ%3D%3D?line=7'>8</a> sklepy = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X34sZmlsZQ%3D%3D?line=8'>9</a> for ind in data.index:
# ...

# %%
# Firmy zachodniopomorskie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_zachodniopomorskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_zachodniopomorskie = firmy_zachodniopomorskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_zachodniopomorskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 27 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X35sZmlsZQ%3D%3D?line=7'>8</a> sklepy = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X35sZmlsZQ%3D%3D?line=8'>9</a> for ind in data.index:
# ...

# %%
# Firmy podlaskie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_podlaskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])
for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_podlaskie = firmy_podlaskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_podlaskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 28 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X36sZmlsZQ%3D%3D?line=6'>7</a> sklepy = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X36sZmlsZQ%3D%3D?line=7'>8</a> for ind in data.index:
# ...

# %%
# Firmy Warmińsko-Mazurskie Wschód
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_warmińsko_mazurskie_wschód = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])
for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_warmińsko_mazurskie_wschód = firmy_warmińsko_mazurskie_wschód.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_warmińsko_mazurskie_wschód
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 29 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X40sZmlsZQ%3D%3D?line=4'>5</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X40sZmlsZQ%3D%3D?line=5'>6</a> sklepy = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X40sZmlsZQ%3D%3D?line=6'>7</a> for ind in data.index:
# ...

# %%
# Firmy Śląskie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 
'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_śląskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])
for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_śląskie = firmy_śląskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_śląskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 30 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X41sZmlsZQ%3D%3D?line=7'>8</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X41sZmlsZQ%3D%3D?line=8'>9</a> sklepy = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X41sZmlsZQ%3D%3D?line=9'>10</a> for ind in data.index:
# ...

# %%
# Firmy dolnośląskie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_dolnośląskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_dolnośląskie = firmy_dolnośląskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_dolnośląskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 31 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X42sZmlsZQ%3D%3D?line=8'>9</a> suma = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X42sZmlsZQ%3D%3D?line=9'>10</a> sklepy = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X42sZmlsZQ%3D%3D?line=10'>11</a> for ind in data.index:
# ...

# %%
# Firmy opolskie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_opolskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_opolskie = firmy_opolskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_opolskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 32 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X43sZmlsZQ%3D%3D?line=6'>7</a> sklepy = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X43sZmlsZQ%3D%3D?line=7'>8</a> for ind in data.index:
# ...

# %%
# Firmy Wielkopolskie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_Wielkopolskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])
for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_Wielkopolskie = firmy_Wielkopolskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_Wielkopolskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 33 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X44sZmlsZQ%3D%3D?line=7'>8</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X44sZmlsZQ%3D%3D?line=8'>9</a> sklepy = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X44sZmlsZQ%3D%3D?line=9'>10</a> for ind in data.index:
# ...

# %%
# Firmy lubelskie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_lubelskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])
for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_lubelskie = firmy_lubelskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_lubelskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 34 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X45sZmlsZQ%3D%3D?line=5'>6</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X45sZmlsZQ%3D%3D?line=6'>7</a> sklepy = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X45sZmlsZQ%3D%3D?line=7'>8</a> for ind in data.index:
# ...

# %%
# Firmy małopolskie (z Grafenem)
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_małopolskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])
for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_małopolskie = firmy_małopolskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_małopolskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 35 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X46sZmlsZQ%3D%3D?line=7'>8</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X46sZmlsZQ%3D%3D?line=8'>9</a> sklepy = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X46sZmlsZQ%3D%3D?line=9'>10</a> for ind in data.index:
# ...

# %%
# Firmy mazowieckie (bez Grafenu)
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ','XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_mazowieckie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_mazowieckie = firmy_mazowieckie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_mazowieckie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 36 in <cell line: 9>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X50sZmlsZQ%3D%3D?line=9'>10</a> suma = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X50sZmlsZQ%3D%3D?line=10'>11</a> sklepy = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X50sZmlsZQ%3D%3D?line=11'>12</a> for ind in data.index:
# ...

# %%
# Firmy łódzkie (bez Grafenu)
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_łódzkie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma and data['Dział'][ind] == 1:
      suma += data['Zmiana wartości N/B'][ind]
  firmy_łódzkie = firmy_łódzkie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_łódzkie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 37 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X51sZmlsZQ%3D%3D?line=7'>8</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X51sZmlsZQ%3D%3D?line=8'>9</a> sklepy = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X51sZmlsZQ%3D%3D?line=9'>10</a> for ind in data.index:
# ...

# %%
# Firmy podkarpackie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_podkarpackie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])
for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_podkarpackie = firmy_podkarpackie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_podkarpackie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 38 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X52sZmlsZQ%3D%3D?line=6'>7</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X52sZmlsZQ%3D%3D?line=7'>8</a> sklepy = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X52sZmlsZQ%3D%3D?line=8'>9</a> for ind in data.index:
# ...

# %%
# Firmy świętokrzyskie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_świętokrzyskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])
for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_świętokrzyskie = firmy_świętokrzyskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_świętokrzyskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 39 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X53sZmlsZQ%3D%3D?line=5'>6</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X53sZmlsZQ%3D%3D?line=6'>7</a> sklepy = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X53sZmlsZQ%3D%3D?line=7'>8</a> for ind in data.index:
# ...

# %%
# Firmy kujawsko_pomorskie 
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_kujawsko_pomorskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_kujawsko_pomorskie = firmy_kujawsko_pomorskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_kujawsko_pomorskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 40 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X54sZmlsZQ%3D%3D?line=7'>8</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X54sZmlsZQ%3D%3D?line=8'>9</a> sklepy = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X54sZmlsZQ%3D%3D?line=9'>10</a> for ind in data.index:
# ...

# %%
# Firmy pomorskie
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_pomorskie = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_pomorskie = firmy_pomorskie.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_pomorskie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 41 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X55sZmlsZQ%3D%3D?line=7'>8</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X55sZmlsZQ%3D%3D?line=8'>9</a> sklepy = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X55sZmlsZQ%3D%3D?line=9'>10</a> for ind in data.index:
# ...

# %%
# Firmy warmińsko_mazurskie_zachód
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_warmińsko_mazurskie_zachód = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  sklepy = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_warmińsko_mazurskie_zachód = firmy_warmińsko_mazurskie_zachód.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_warmińsko_mazurskie_zachód
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 42 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X56sZmlsZQ%3D%3D?line=6'>7</a> suma = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X56sZmlsZQ%3D%3D?line=7'>8</a> sklepy = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X56sZmlsZQ%3D%3D?line=8'>9</a> for ind in data.index:
# ...

# %%
#Export - Białoruś
lista = ['XYZ', 'XYZ', 'XYZ']
firmy_export_białoruś = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_export_białoruś = firmy_export_białoruś.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_export_białoruś
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 43 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X60sZmlsZQ%3D%3D?line=4'>5</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X60sZmlsZQ%3D%3D?line=5'>6</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X60sZmlsZQ%3D%3D?line=6'>7</a>   for ind in data.index:
# ...

# %%
#Export - Estonia
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_export_estonia = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_export_estonia = firmy_export_estonia.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_export_estonia
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 44 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X61sZmlsZQ%3D%3D?line=5'>6</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X61sZmlsZQ%3D%3D?line=6'>7</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X61sZmlsZQ%3D%3D?line=7'>8</a>   for ind in data.index:
# ...

# %%
#Export - Litwa
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_export_litwa = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_export_litwa = firmy_export_litwa.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_export_litwa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 45 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X62sZmlsZQ%3D%3D?line=6'>7</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X62sZmlsZQ%3D%3D?line=7'>8</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X62sZmlsZQ%3D%3D?line=8'>9</a>   for ind in data.index:
# ...

# %%
#Export - Gruzja
lista = ['XYZ']
firmy_export_gruzja = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_export_gruzja = firmy_export_gruzja.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_export_gruzja
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 46 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X63sZmlsZQ%3D%3D?line=4'>5</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X63sZmlsZQ%3D%3D?line=5'>6</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X63sZmlsZQ%3D%3D?line=6'>7</a>   for ind in data.index:
# ...

# %%
#Export - Łotwa
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
firmy_export_łotwa = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_export_łotwa = firmy_export_łotwa.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_export_łotwa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 47 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X64sZmlsZQ%3D%3D?line=4'>5</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X64sZmlsZQ%3D%3D?line=5'>6</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X64sZmlsZQ%3D%3D?line=6'>7</a>   for ind in data.index:
# ...

# %%
#Export - Czechy
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',]
firmy_export_czechy = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_export_czechy = firmy_export_czechy.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_export_czechy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 48 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X65sZmlsZQ%3D%3D?line=6'>7</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X65sZmlsZQ%3D%3D?line=7'>8</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X65sZmlsZQ%3D%3D?line=8'>9</a>   for ind in data.index:
# ...

# %%
#Export - Inni
lista = ['XYZ', 'XYZ']
firmy_export_inni = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_export_inni = firmy_export_inni.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_export_inni
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 49 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X66sZmlsZQ%3D%3D?line=4'>5</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X66sZmlsZQ%3D%3D?line=5'>6</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#X66sZmlsZQ%3D%3D?line=6'>7</a>   for ind in data.index:
# ...

# %%
#Export - Słowacja
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',
'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ',]
firmy_export_słowacja = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_export_słowacja = firmy_export_słowacja.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_export_słowacja
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 50 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y100sZmlsZQ%3D%3D?line=6'>7</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y100sZmlsZQ%3D%3D?line=7'>8</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y100sZmlsZQ%3D%3D?line=8'>9</a>   for ind in data.index:
# ...

# %%
#Export - Ukraina
lista = ['XYZ']
firmy_export_ukraina = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Nazwa'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  firmy_export_ukraina = firmy_export_ukraina.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
firmy_export_ukraina
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 51 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y101sZmlsZQ%3D%3D?line=4'>5</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y101sZmlsZQ%3D%3D?line=5'>6</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y101sZmlsZQ%3D%3D?line=6'>7</a>   for ind in data.index:
# ...

# %%
#Sklepy 
lista = [101, 102, 103, 104, 105, 107, 108, 109]
sklepy = pd.DataFrame(columns = ['Firma', 'Wynik Netto'])

for firma in lista:
  suma = 0
  for ind in data.index:
    if data['Dział'][ind] == firma :
      suma += data['Zmiana wartości N/B'][ind]
  sklepy = sklepy.append({'Firma':firma, 'Wynik Netto':suma} ,ignore_index= True)
sklepy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 52 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y102sZmlsZQ%3D%3D?line=4'>5</a> for firma in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y102sZmlsZQ%3D%3D?line=5'>6</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y102sZmlsZQ%3D%3D?line=6'>7</a>   for ind in data.index:
# ...

# %%
#Export 
lista = ['XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ', 'XYZ']
export = pd.DataFrame(columns = ['Kraj', 'Wynik Netto'])

for kraj in lista:
  suma = 0
  for ind in data.index:
    if data['Kod kraju'][ind] == kraj and data['Dział'][ind] == 4 :
      suma += data['Zmiana wartości N/B'][ind]
  export = export.append({'Firma':kraj, 'Wynik Netto':suma} ,ignore_index= True)
export
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 53 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y103sZmlsZQ%3D%3D?line=4'>5</a> for kraj in lista:
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y103sZmlsZQ%3D%3D?line=5'>6</a>   suma = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y103sZmlsZQ%3D%3D?line=6'>7</a>   for ind in data.index:
# ...

# %%
kraje_H24 = data[data['Numerator_MPK'] == 5]['Kod kraju'].unique()
h24 = pd.DataFrame(columns = ['Kraj', 'Wynik Netto'])
for kraj in kraje_H24:
  suma = 0
  for ind in data.index:
    if (data['Kod kraju'][ind] == kraj and data['Numerator_MPK'][ind] == 5):
      suma += data['Zmiana wartości N/B'][ind]
  h24 = h24.append({'Kraj':kraj, 'Wynik Netto':suma} ,ignore_index= True)
h24
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 54 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> kraje_H24 = data[data['Numerator_MPK'] == 5]['Kod kraju'].unique()
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y104sZmlsZQ%3D%3D?line=1'>2</a> h24 = pd.DataFrame(columns = ['Kraj', 'Wynik Netto'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y104sZmlsZQ%3D%3D?line=2'>3</a> for kraj in kraje_H24:
#
# NameError: name 'data' is not defined

# %%
data_to_excel.to_excel(writer, sheet_name = 'RKS')
kf_ramka.to_excel(writer, sheet_name = 'KF')
sieci_handlowe.to_excel(writer, sheet_name = 'Sieci handlowe')
data_to_excel_2.to_excel(writer, sheet_name = 'KK')
kluczowi_klienci.to_excel(writer,sheet_name = 'KK firmy')
firmy_lubuskie.to_excel(writer, sheet_name= 'Firmy lubuskie')
firmy_zachodniopomorskie.to_excel(writer, sheet_name= 'Firmy zachodniopomorskie')
firmy_podlaskie.to_excel(writer, sheet_name= 'Firmy podlaskie')
firmy_warmińsko_mazurskie_wschód.to_excel(writer, sheet_name= 'Firmy WM Wschód')
firmy_śląskie.to_excel(writer, sheet_name= 'Firmy śląskie')
firmy_dolnośląskie.to_excel(writer, sheet_name= 'Firmy dolnośląskie')
firmy_opolskie.to_excel(writer, sheet_name= 'Firmy opolskie')
firmy_Wielkopolskie.to_excel(writer, sheet_name= 'Firmy wielkopolskie')
firmy_lubelskie.to_excel(writer, sheet_name= 'Firmy lubelskie')
firmy_małopolskie.to_excel(writer, sheet_name= 'Firmy małopolskie')
firmy_mazowieckie.to_excel(writer, sheet_name= 'Firmy mazowieckie')
firmy_łódzkie.to_excel(writer, sheet_name= 'Firmy łódzkie')
firmy_podkarpackie.to_excel(writer, sheet_name='Firmy podkarpackie')
firmy_świętokrzyskie.to_excel(writer, sheet_name= 'Firmy świętokrzyskie')
firmy_kujawsko_pomorskie.to_excel(writer, sheet_name= 'Firmy kujawsko-pomorskie')
firmy_pomorskie.to_excel(writer, sheet_name= 'Firmy pomorskie')
firmy_warmińsko_mazurskie_zachód.to_excel(writer, sheet_name= 'Firmy WM Zachód')
firmy_export_białoruś.to_excel(writer, sheet_name= "Export - Białoruś")
firmy_export_estonia.to_excel(writer, sheet_name= 'Export - Estonia')
firmy_export_litwa.to_excel(writer, sheet_name= 'Export - Litwa')
firmy_export_gruzja.to_excel(writer, sheet_name= ' Export - Gruzja')
firmy_export_łotwa.to_excel(writer, sheet_name= 'Export - Łotwa')
firmy_export_czechy.to_excel(writer, sheet_name= 'Export - Czechy')
firmy_export_inni.to_excel(writer, sheet_name='Export - inni')
firmy_export_słowacja.to_excel(writer, sheet_name='Export - Słowacja')
firmy_export_ukraina.to_excel(writer, sheet_name= 'Export - Ukraina')
sklepy.to_excel(writer, sheet_name= 'Sklepy')
export.to_excel(writer, sheet_name= 'Export')
h24.to_excel(writer, sheet_name= 'H24')
writer.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Konrad\Desktop\Raport_dzienny_obroty_wszystko ENOVA_poziom_zestawień.ipynb Komórka 55 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> data_to_excel.to_excel(writer, sheet_name = 'RKS')
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y105sZmlsZQ%3D%3D?line=1'>2</a> kf_ramka.to_excel(writer, sheet_name = 'KF')
#       <a href='vscode-notebook-cell:/c%3A/Users/Konrad/Desktop/Raport_dzienny_obroty_wszystko%20ENOVA_poziom_zestawie%C5%84.ipynb#Y105sZmlsZQ%3D%3D?line=2'>3</a> sieci_handlowe.to_excel(writer, sheet_name = 'Sieci handlowe')
#
# NameError: name 'data_to_excel' is not defined
